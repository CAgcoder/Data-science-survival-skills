# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Fau/2WS/DSSS/home work/Homework_3/census_income_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  AGE   WORKCLASS  FNLWGT      EDUCATION  EDUCATION-NUM  \
# 0           0   25     Private  226802           11th              7
# 1           1   38     Private   89814        HS-grad              9
# 2           2   28   Local-gov  336951     Assoc-acdm             12
# 3           3   44     Private  160323   Some-college             10
# 4           4   18           ?  103497   Some-college             10
#
#         MARITAL STATUS          OCCUPATION RELATIONSHIP    RACE      SEX  \
# 0        Never-married   Machine-op-inspct    Own-child   Black     Male
# 1   Married-civ-spouse     Farming-fishing      Husband   White     Male
# 2   Married-civ-spouse     Protective-serv      Husband   White     Male
# 3   Married-civ-spouse   Machine-op-inspct      Husband   Black     Male
# 4        Never-married                   ?    Own-child   White   Female
#
#    CAPITAL-GAIN  CAPITAL-LOSS  HOURS-PER-WEEK  NATIVE-COUNTRY  SALARY
# ...

# %%
len(df)
# Out:
# 16281

# %%
df = df[~df["AGE"].isnull()]
len(df)
# Out:
# 16281

# %%
df["AGE"].plot.hist(bins = 20)
plt.xlabel("Age")
plt.title("a)  Age distribution of respondents")
plt.show()

# %%
df = pd.read_csv("D:/Fau/2WS/DSSS/home work/Homework_3/census_income_dataset.csv")
len(df)
# Out:
# 16281

# %%
df[~df["RELATIONSHIP"].isnull()]
len(df)
# Out:
# 16281

# %%
df["RELATIONSHIP"].value_counts().plot(kind = "pie")
plt.title("b)  Relationship status.")
plt.axis("off")
plt.show()

# %%
df = pd.read_csv("D:/Fau/2WS/DSSS/home work/Homework_3/census_income_dataset.csv")
len(df)
# Out:
# 16281

# %%
df = df[~df["EDUCATION"].isnull()]
len(df)
# Out:
# 16281

# %%
df = df[~df["SALARY"].isnull()]
len(df)
# Out:
# 16281

# %%
df.loc[df["SALARY"] == " <=50K","SALARY"] = 0
df.loc[df["SALARY"] == " >50K","SALARY"] = 1
df
# Out:
#        Unnamed: 0  AGE      WORKCLASS  FNLWGT      EDUCATION  EDUCATION-NUM  \
# 0               0   25        Private  226802           11th              7
# 1               1   38        Private   89814        HS-grad              9
# 2               2   28      Local-gov  336951     Assoc-acdm             12
# 3               3   44        Private  160323   Some-college             10
# 4               4   18              ?  103497   Some-college             10
# ...           ...  ...            ...     ...            ...            ...
# 16276       16276   39        Private  215419      Bachelors             13
# 16277       16277   64              ?  321403        HS-grad              9
# 16278       16278   38        Private  374983      Bachelors             13
# 16279       16279   44        Private   83891      Bachelors             13
# 16280       16280   35   Self-emp-inc  182148      Bachelors             13
#
# ...

# %%
df["SALARY"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='SALARY'>

# %%
# from scipy.stats import pearsonr, spearmanr
# corr, p_value = pearsonr(df["EDUCATION"],df["SALARY"])
# corr

# %%
df["EDUCATION"].value_counts(sort=False,normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["SALARY"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df = df[df["SALARY"] == 1]
df
# Out:
#        Unnamed: 0  AGE          WORKCLASS  FNLWGT      EDUCATION  \
# 2               2   28          Local-gov  336951     Assoc-acdm
# 3               3   44            Private  160323   Some-college
# 7               7   63   Self-emp-not-inc  104626    Prof-school
# 10             10   65            Private  184454        HS-grad
# 14             14   48            Private  279724        HS-grad
# ...           ...  ...                ...     ...            ...
# 16254       16254   38            Private  149347        Masters
# 16255       16255   43          Local-gov   23157        Masters
# 16261       16261   40            Private  202168    Prof-school
# 16265       16265   50          Local-gov  139347        Masters
# 16280       16280   35       Self-emp-inc  182148      Bachelors
#
#        EDUCATION-NUM       MARITAL STATUS          OCCUPATION RELATIONSHIP  \
# 2                 12   Married-civ-spouse     Protective-serv      Husband
# ...

# %%
df["EDUCATION"].value_counts(sort=False,normalize=True).plot.bar()
df
# Out:
#        Unnamed: 0  AGE          WORKCLASS  FNLWGT      EDUCATION  \
# 2               2   28          Local-gov  336951     Assoc-acdm
# 3               3   44            Private  160323   Some-college
# 7               7   63   Self-emp-not-inc  104626    Prof-school
# 10             10   65            Private  184454        HS-grad
# 14             14   48            Private  279724        HS-grad
# ...           ...  ...                ...     ...            ...
# 16254       16254   38            Private  149347        Masters
# 16255       16255   43          Local-gov   23157        Masters
# 16261       16261   40            Private  202168    Prof-school
# 16265       16265   50          Local-gov  139347        Masters
# 16280       16280   35       Self-emp-inc  182148      Bachelors
#
#        EDUCATION-NUM       MARITAL STATUS          OCCUPATION RELATIONSHIP  \
# 2                 12   Married-civ-spouse     Protective-serv      Husband
# ...

# %%
df = pd.read_csv("D:/Fau/2WS/DSSS/home work/Homework_3/census_income_dataset.csv")
df
# Out:
#        Unnamed: 0  AGE      WORKCLASS  FNLWGT      EDUCATION  EDUCATION-NUM  \
# 0               0   25        Private  226802           11th              7
# 1               1   38        Private   89814        HS-grad              9
# 2               2   28      Local-gov  336951     Assoc-acdm             12
# 3               3   44        Private  160323   Some-college             10
# 4               4   18              ?  103497   Some-college             10
# ...           ...  ...            ...     ...            ...            ...
# 16276       16276   39        Private  215419      Bachelors             13
# 16277       16277   64              ?  321403        HS-grad              9
# 16278       16278   38        Private  374983      Bachelors             13
# 16279       16279   44        Private   83891      Bachelors             13
# 16280       16280   35   Self-emp-inc  182148      Bachelors             13
#
# ...

# %%
edu = df["EDUCATION"].value_counts()
edu
# Out:
#  HS-grad         5283
#  Some-college    3587
#  Bachelors       2670
#  Masters          934
#  Assoc-voc        679
#  11th             637
#  Assoc-acdm       534
#  10th             456
#  7th-8th          309
#  Prof-school      258
#  9th              242
#  12th             224
#  Doctorate        181
#  5th-6th          176
#  1st-4th           79
#  Preschool         32
# Name: EDUCATION, dtype: int64

# %%
j = df[df["SALARY"] == " >50K"]
num = j["EDUCATION"].value_counts()
num
# Out:
#  Bachelors       1092
#  HS-grad          828
#  Some-college     676
#  Masters          500
#  Prof-school      194
#  Assoc-voc        161
#  Assoc-acdm       148
#  Doctorate        125
#  11th              32
#  10th              25
#  7th-8th           22
#  12th              15
#  9th               14
#  5th-6th           11
#  1st-4th            2
#  Preschool          1
# Name: EDUCATION, dtype: int64

# %%
keys = df["EDUCATION"].value_counts().keys()
keys
# Out:
# Index([' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc',
#        ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th',
#        ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool'],
#       dtype='object')

# %%
pop = []
for i in keys:
    por = num[i]/edu[i]
    pop.append(por)
pop = pd.Series(pop,keys)
plt.title("c)  Educational level and salary")
pop.plot.bar()
pop
# Out:
#  HS-grad         0.156729
#  Some-college    0.188458
#  Bachelors       0.408989
#  Masters         0.535332
#  Assoc-voc       0.237113
#  11th            0.050235
#  Assoc-acdm      0.277154
#  10th            0.054825
#  7th-8th         0.071197
#  Prof-school     0.751938
#  9th             0.057851
#  12th            0.066964
#  Doctorate       0.690608
#  5th-6th         0.062500
#  1st-4th         0.025316
#  Preschool       0.031250
# dtype: float64

# %%
df = pd.read_csv("D:/Fau/2WS/DSSS/home work/Homework_3/census_income_dataset.csv")

# %%
df.loc[df["SEX"] == " Female","SEX"] = 0
df.loc[df["SEX"] == " Male","SEX"] = 1
gen = df["SEX"].value_counts()
gen
# Out:
# 1    10860
# 0     5421
# Name: SEX, dtype: int64

# %%
df.loc[df["SALARY"] == " <=50K","SALARY"] = 0
df.loc[df["SALARY"] == " >50K","SALARY"] = 1

sal = df[df["SALARY"] == 1]
sal = sal["SEX"].value_counts()
sal
# Out:
# 1    3256
# 0     590
# Name: SEX, dtype: int64

# %%
rac = df["RACE"].value_counts()
rac
# Out:
#  White                 13946
#  Black                  1561
#  Asian-Pac-Islander      480
#  Amer-Indian-Eskimo      159
#  Other                   135
# Name: RACE, dtype: int64

# %%
race = df[df["SALARY"] == 1]
race = race["RACE"].value_counts()
race
# Out:
#  White                 3490
#  Black                  179
#  Asian-Pac-Islander     133
#  Other                   25
#  Amer-Indian-Eskimo      19
# Name: RACE, dtype: int64

# %%
from scipy.stats import pearsonr, spearmanr
corr, p_value = pearsonr(df["SEX"], df["SALARY"])
corr
# Out:
# 0.21189201138169
